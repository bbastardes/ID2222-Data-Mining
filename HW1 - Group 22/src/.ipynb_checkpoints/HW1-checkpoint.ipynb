// %%
import org.apache.spark.SparkConf
import org.apache.spark.SparkContext
import org.apache.spark.rdd.RDD
// Out:
// Intitializing Scala interpreter ...
// Spark Web UI available at http://DESKTOP-OGTOHVK:4040
// SparkContext available as 'sc' (version = 3.0.1, master = local[*], app id = local-1604958223595)
// SparkSession available as 'spark'
// import org.apache.spark.SparkConf
// import org.apache.spark.SparkContext
// import org.apache.spark.rdd.RDD

// %% [markdown]
// ## Class definition

// %%
class Shingle {
    
    def createshingles(path: String, k:Int) : RDD[(String, Set[Int])] = {
        val files = sc.wholeTextFiles(path,1).map({ case (path, text) => (path.split("/").last, text) })
                                            .mapValues(_.toLowerCase)
                                            .mapValues(_.replace(",", ""))
                                            .mapValues(_.replace(".", ""))
                                            .mapValues(_.replace("?", ""))
                                            .mapValues(_.replace("!", ""))
                                            .mapValues(_.replace(")", ""))
                                            .mapValues(_.replace("(", ""))    
        val shingles = files.flatMapValues { case (str) => str.sliding(k,1)
        }  
        print(shingles.collect)
        return shingles.mapValues(str => str.hashCode()).groupByKey().mapValues(x => x.toSet)
    }
}


class CompareSet {
  def JaccardSimilarity(set1: Set[(Int)], set2: Set[(Int)]) : Double = {
    return ((set1.intersect(set2).size).toDouble / (set1.union(set2).size)).toDouble
  }
}

implicit def bool2int(b:Boolean) = if (b) 1 else 0
import scala.util.control._

class MinHashing {
    
  def create_chrMatrix(shingles_set: Array[(Int)], set: Array[(Int)]) : Array[(Int)] = {
    val chr_col = Array.fill(shingles_set.size)(0)
      for (i <- 0 to shingles_set.size-1){
        chr_col(i) = (set contains shingles_set(i))*1
      }
    return chr_col
  }
    
  def h(x: Int, a:Int, rows:Int) : Int =  {
        return (((x+1)*a)+1)%rows
    }

  def create_signature(shingles_set: Array[(Int)], set: Array[(Int)], permutations: Int) : Array[(Int)] = {
      val chr_col = create_chrMatrix(shingles_set, set)
      val signature = Array.fill(permutations)(0)
      val rows = chr_col.size
      val inloop = new Breaks
          for (a <- 1 to permutations){
              inloop.breakable{
              for (x <- 0 to chr_col.size-1){
                  if (chr_col(h(x,a,rows))==1){
                      signature(a-1) = x+1
                      inloop.break
                      }
                  }
              }
          }
      return signature
  }
    
}

class CompareSignatures {
    
   def similarity(signature0: Array[(Int)], signature1: Array[(Int)]) : Double = {
       val sign0 = signature0.toList
       val sign1 = signature1.toList
       return (sign0.zip(sign1).filter(x => x._1 == x._2).size).toDouble/signature0.size.toDouble
    } 
}

import scala.collection.mutable.ListBuffer

class LocSensHashing{
    
    def candidate_pairs(signatures: Vector[(String, Array[Int])], r: Int) : Vector[(String, String)] = {
        
        val loc_hash = for (i <- 0 to signatures.size-1) yield((signatures(i)._1,
                                                (for (x <- (signatures(i)._2.toList).grouped(r)) yield(x.hashCode())).toList))
        
        val candidates = new ListBuffer[(String, String)]()
        
        for (i <- 0 to signatures.size-1){
            for (j <- i+1 to signatures.size-1){
               if ((loc_hash(i)._2.zip(loc_hash(j)._2).filter(x => x._1 == x._2).size) > 0){
                   candidates += ((signatures(i)._1, signatures(j)._1))
                   //println(signatures(i)._1, signatures(j)._1)
               }
            }
        }
        return candidates.toVector
    }
}
// Out:
// warning: there was one feature warning; for details, enable `:setting -feature' or `:replay -feature'
// defined class Shingle
// defined class CompareSet
// bool2int: (b: Boolean)Int
// import scala.util.control._
// defined class MinHashing
// defined class CompareSignatures
// import scala.collection.mutable.ListBuffer
// defined class LocSensHashing

// %% [markdown]
// ---

// %%
// parameters

val path = "../data/*_taska.txt"
val k = 7
// Out:
// path: String = ../data/*_taska.txt
// k: Int = 7

// %%
// Create shingles

val shing = new Shingle
val shingles = shing.createshingles(path,k)
val s = shingles.collect()
// Out:
// [Lscala.Tuple2;@170fa2b4
// shing: Shingle = Shingle@4b1e6aef
// shingles: org.apache.spark.rdd.RDD[(String, Set[Int])] = MapPartitionsRDD[13] at mapValues at <console>:29
// s: Array[(String, Set[Int])] = Array((g0pE_taska.txt,Set(1024328849, -809942811, 300626, 450333591, -1110351275, 2057428624, 1237394832, -719776277, 877982873, -1509224606, -1348893292, -422012319, 1772178932, -974723696, -604869464, 1718732402, -1897320720, 2129320190, 1217550084, -1351981020, -1542092980, -1956689524, 1979091318, -679719782, -887312734, 667020100, 254387060, 735439297, 1219629894, 1930547162, 1195890950, -1922170827, 833328706, -1911224770, 700148195, -493883412, -1433668758, -1494609322, -1191026030, 1361461549, -1311872163, 1606945631, 939821247, 1216975005, 254386680, 1020649433, 280184718, -77600629, -421994171, 1998498434,...

// %%
// Compute similarity

val similarity = new CompareSet
val set_size = s.size-1

for (i <- 0 to set_size){
    for (j <- i+1 to set_size){
        val sim = similarity.JaccardSimilarity(s(i)._2,s(j)._2)
        println("("+s(i)._1+","+s(j)._1+"):"+sim)
    }
}
// Out:
// (g0pE_taska.txt,g0pC_taska.txt):0.15293080652269722
// (g0pE_taska.txt,g1pA_taska.txt):0.05274000824062629
// (g0pE_taska.txt,g3pC_taska.txt):0.37671641791044774
// (g0pE_taska.txt,g0pD_taska.txt):0.5091230135373749
// (g0pE_taska.txt,g0pB_taska.txt):0.04813432835820895
// (g0pE_taska.txt,g4pD_taska.txt):0.22662367572547212
// (g0pE_taska.txt,g3pA_taska.txt):0.06424344885883347
// (g0pE_taska.txt,g1pB_taska.txt):0.04103671706263499
// (g0pE_taska.txt,g4pC_taska.txt):0.8371958285052143
// (g0pE_taska.txt,g2pE_taska.txt):0.5117101193106496
// (g0pE_taska.txt,g2pA_taska.txt):0.03694581280788178
// (g0pE_taska.txt,g2pB_taska.txt):0.03636363636363636
// (g0pE_taska.txt,orig_taska.txt):0.8897228637413395
// (g0pE_taska.txt,g4pE_taska.txt):0.09837467921300257
// (g0pE_taska.txt,g0pA_taska.txt):0.05443548387096774
// (g0pE_taska.txt,g2pC_taska.txt):0.36591606960081885
// (g0pE_taska.txt,g3pB_taska.txt):0.05779889152810768
// (g0pE_taska.txt,g4pB_taska.txt):0.03252710592160134
// (g2pA_taska.txt,g2pB_taska.txt):0.056247316444826105
// (g2pA_taska.txt,orig_taska.txt):0.03771661569826707
// (g2pA_taska.txt,g4pE_taska.txt):0.03662842012356576
// (g2pA_taska.txt,g0pA_taska.txt):0.04537521815008726
// (g2pA_taska.txt,g2pC_taska.txt):0.037695891571368066
// (g2pA_taska.txt,g3pB_taska.txt):0.06190476190476191
// (g2pA_taska.txt,g4pB_taska.txt):0.041051660516605165
// (g2pA_taska.txt,g1pD_taska.txt):0.04202020202020202
// (g2pB_taska.txt,orig_taska.txt):0.036458333333333336
// (g2pB_taska.txt,g4pE_taska.txt):0.0431077694235589
// (g2pB_taska.txt,g0pA_taska.txt):0.08295165394402036
// (g2pB_taska.txt,g2pC_taska.txt):0.04351984696317551
// (g2pB_taska.txt,g3pB_taska.txt):0.06429615197272284
// (g2pB_taska.txt,g4pB_taska.txt):0.08274360370168754
// (g2pB_taska.txt,g1pD_taska.txt):0.038185085354896675
// (orig_taska.txt,g4pE_taska.txt):0.09406952965235174
// (orig_taska.txt,g0pA_taska.txt):0.05259087393658159
// (orig_taska.txt,g2pC_taska.txt):0.35546875
// (orig_taska.txt,g3pB_taska.txt):0.05705591479650057
// (orig_taska.txt,g4pB_taska.txt):0.034441329595514616
// (orig_taska.txt,g1pD_taska.txt):0.22677364864864866
// (g4pE_taska.txt,g0pA_taska.txt):0.04833679833679834
// (g4pE_taska.txt,g2pC_taska.txt):0.046488125315816066
// (g4pE_taska.txt,g3pB_taska.txt):0.04959514170040486
// (g4pE_taska.txt,g4pB_taska.txt):0.04159733777038269
// (g4pE_taska.txt,g1pD_taska.txt):0.08857001484413657
// (g0pA_taska.txt,g2pC_taska.txt):0.04437869822485207
// (g0pA_taska.txt,g3pB_taska.txt):0.09048843187660668
// (g0pA_taska.txt,g4pB_taska.txt):0.04904632152588556
// (g0pA_taska.txt,g1pD_taska.txt):0.04755244755244755
// (g2pC_taska.txt,g3pB_taska.txt):0.05428986912263694
// (g2pC_taska.txt,g4pB_taska.txt):0.04377637130801688
// (g2pC_taska.txt,g1pD_taska.txt):0.16802030456852793
// (g3pB_taska.txt,g4pB_taska.txt):0.061027837259100645
// (g3pB_taska.txt,g1pD_taska.txt):0.04918032786885246
// (g4pB_taska.txt,g1pD_taska.txt):0.03638151425762045
// similarity: CompareSet = CompareSet@4604898a
// set_size: Int = 19

// %%
//MinHashing

// create common set of shingles
val shingles_list = scala.util.Random.shuffle(
                    ((for (x <- 0 to set_size) yield (s(x)._2).toList).flatten).distinct).toArray

// create the signature matrix
val minhash = new MinHashing
val permutations = 500

val sign_list = (for (x <- 0 to set_size) 
                 yield ((s(x)_1,minhash.create_signature(shingles_list, (s(x)_2).toArray, permutations))))
// Out:
// warning: there were two feature warnings; for details, enable `:setting -feature' or `:replay -feature'
// shingles_list: Array[Int] = Array(2052199687, 465274701, 1082360966, 1020707379, 887774253, 811894694, -350894934, 1355077647, 1759907180, -1382560443, 2132203331, -847129240, 1851088000, 1548740585, 1020483038, -1542215320, 1216975050, 772374856, 1424174259, 1099962727, -1526084049, -1542092970, 688529837, 678775251, 1096807053, 1755417433, 1020414949, 1247079257, 1356836820, -9512916, 1364391596, -417485081, 1982508106, 1448660110, 1930547162, 1513864891, 772452404, 181521592, -1554573899, 810971266, -322704102, -294256262, -1349736766, -430106886, 1755417649, -9516112, 1084750166, 1127681549, 1887329618, -889033391, -1881759116, 1421108136, -492531348, -1048644037, -1542092266, 758779685, -1596131519, 1268784658, -1521981224, 1915918929, -924706444, -1349523962, 1771511527, 200739438...

// %%
// Signatures comparison

val compSign = new CompareSignatures

for (i <- 0 to set_size){
    for (j <- i+1 to set_size){
        val sim = compSign.similarity(sign_list(i)._2,sign_list(j)._2)
        println("("+sign_list(i)._1+","+sign_list(j)._1+"):"+sim)
    }
}
// Out:
// (g0pE_taska.txt,g0pC_taska.txt):0.132
// (g0pE_taska.txt,g1pA_taska.txt):0.038
// (g0pE_taska.txt,g3pC_taska.txt):0.348
// (g0pE_taska.txt,g0pD_taska.txt):0.494
// (g0pE_taska.txt,g0pB_taska.txt):0.026
// (g0pE_taska.txt,g4pD_taska.txt):0.242
// (g0pE_taska.txt,g3pA_taska.txt):0.04
// (g0pE_taska.txt,g1pB_taska.txt):0.026
// (g0pE_taska.txt,g4pC_taska.txt):0.842
// (g0pE_taska.txt,g2pE_taska.txt):0.496
// (g0pE_taska.txt,g2pA_taska.txt):0.032
// (g0pE_taska.txt,g2pB_taska.txt):0.028
// (g0pE_taska.txt,orig_taska.txt):0.9
// (g0pE_taska.txt,g4pE_taska.txt):0.11
// (g0pE_taska.txt,g0pA_taska.txt):0.044
// (g0pE_taska.txt,g2pC_taska.txt):0.346
// (g0pE_taska.txt,g3pB_taska.txt):0.038
// (g0pE_taska.txt,g4pB_taska.txt):0.014
// (g0pE_taska.txt,g1pD_taska.txt):0.252
// (g0pC_taska.txt,g1pA_taska.txt):0.06
// (g0pC_taska.txt,g3pC_taska.txt):0.08
// (g0pC_taska.txt,g0pD_taska.txt):0.154
// (g0pC_taska.txt,g0pB_taska.txt):0.046
// (g0pC_taska.txt,g4pD_taska.txt):0.074
// (g0pC_taska.txt,g3pA_taska.txt):0.032
// (g0pC_taska.txt,g1pB_taska.txt):0.076
// (g0pC_taska.txt,g4pC_taska.txt):0.136
// (g0pC_taska.txt,g2pE_taska.txt):0.132
// (g0pC_taska.txt,g2pA_taska.txt):0.048
// (g0pC_taska.txt,g2pB_taska.txt):0.054
// (g0pC_taska.txt,orig_taska.txt):0.132
// (g0pC_taska.txt,g4pE_taska.txt):0.046
// (g0pC_taska.txt,g0pA_taska.txt):0.06
// (g0pC_taska.txt,g2pC_taska.txt):0.146
// (g0pC_taska.txt,g3pB_taska.txt):0.05
// (g0pC_taska.txt,g4pB_taska.txt):0.064
// (g0pC_taska.txt,g1pD_taska.txt):0.122
// (g1pA_taska.txt,g3pC_taska.txt):0.054
// (g2pE_taska.txt,g2pA_taska.txt):0.028
// (g2pE_taska.txt,g2pB_taska.txt):0.04
// (g2pE_taska.txt,orig_taska.txt):0.46
// (g2pE_taska.txt,g4pE_taska.txt):0.082
// (g2pE_taska.txt,g0pA_taska.txt):0.04
// (g2pE_taska.txt,g2pC_taska.txt):0.218
// (g2pE_taska.txt,g3pB_taska.txt):0.038
// (g2pE_taska.txt,g4pB_taska.txt):0.016
// (g2pE_taska.txt,g1pD_taska.txt):0.15
// (g2pA_taska.txt,g2pB_taska.txt):0.046
// (g2pA_taska.txt,orig_taska.txt):0.034
// (g2pA_taska.txt,g4pE_taska.txt):0.034
// (g2pA_taska.txt,g0pA_taska.txt):0.058
// (g2pA_taska.txt,g2pC_taska.txt):0.046
// (g2pA_taska.txt,g3pB_taska.txt):0.034
// (g2pA_taska.txt,g4pB_taska.txt):0.046
// (g2pA_taska.txt,g1pD_taska.txt):0.036
// (g2pB_taska.txt,orig_taska.txt):0.028
// (g2pB_taska.txt,g4pE_taska.txt):0.034
// (g2pB_taska.txt,g0pA_taska.txt):0.072
// (g2pB_taska.txt,g2pC_taska.txt):0.052
// (g2pB_taska.txt,g3pB_taska.txt):0.06
// (g2pB_taska.txt,g4pB_taska.txt):0.078
// (g2pB_taska.txt,g1pD_taska.txt):0.036
// (orig_taska.txt,g4pE_taska.txt):0.102
// (orig_taska.txt,g0pA_taska.txt):0.05
// (orig_taska.txt,g2pC_taska.txt):0.324
// (orig_taska.txt,g3pB_taska.txt):0.036
// (orig_taska.txt,g4pB_taska.txt):0.018
// (orig_taska.txt,g1pD_taska.txt):0.248
// (g4pE_taska.txt,g0pA_taska.txt):0.038
// (g4pE_taska.txt,g2pC_taska.txt):0.032
// (g4pE_taska.txt,g3pB_taska.txt):0.048
// (g4pE_taska.txt,g4pB_taska.txt):0.036
// (g4pE_taska.txt,g1pD_taska.txt):0.084
// (g0pA_taska.txt,g2pC_taska.txt):0.038
// (g0pA_taska.txt,g3pB_taska.txt):0.08
// (g0pA_taska.txt,g4pB_taska.txt):0.054
// (g0pA_taska.txt,g1pD_taska.txt):0.046
// (g2pC_taska.txt,g3pB_taska.txt):0.026
// (g2pC_taska.txt,g4pB_taska.txt):0.014
// (g2pC_taska.txt,g1pD_taska.txt):0.178
// (g3pB_taska.txt,g4pB_taska.txt):0.062
// (g3pB_taska.txt,g1pD_taska.txt):0.022
// (g4pB_taska.txt,g1pD_taska.txt):0.032
// compSign: CompareSignatures = CompareSignatures@6c9bca53

// %%
// Local-Sensitive Hashing

val t = 0.8
val b = 50
val r = 10

val LSH = new LocSensHashing
val cand = LSH.candidate_pairs(sign_list.toVector, r);
// Out:
// t: Double = 0.74
// b: Int = 50
// r: Int = 10
// LSH: LocSensHashing = LocSensHashing@82abfb9
// cand: Vector[(String, String)] = Vector((g0pE_taska.txt,g4pC_taska.txt), (g0pE_taska.txt,orig_taska.txt), (g4pC_taska.txt,orig_taska.txt))
